# %%
# this will download papers from my ORCID *when there is a DOI available*. If there is no DOI available then need to manually add the work to the my_cv_data google sheet (e.g. book chapter)

import pandas as pd
import requests
import json

_id="0000-0002-0408-5801"

r = requests.get(f"https://pub.orcid.org/v3.0/{_id}/works",
                headers = {'User-Agent':'Mozilla/5.0', 'accept' : 'application/json'})
r=r.json()

titles=[]
journals=[]
years=[]
doi_URLs=[]
dois=[]
author_names=[]


for work in range(len(r['group'])):
    titles.append(r['group'][work]['work-summary'][0]['title']['title']['value'])
    journals.append(r['group'][work]['work-summary'][0]['journal-title']['value'])
    years.append(r['group'][work]['work-summary'][0]['publication-date']['year']['value'])
    
    for ext_id in range(len(r['group'][work]['work-summary'][0]['external-ids']['external-id'])):
        if r['group'][work]['work-summary'][0]['external-ids']['external-id'][ext_id]['external-id-type']=='doi':
            doi_URLs.append(r['group'][work]['work-summary'][0]['external-ids']['external-id'][ext_id]['external-id-url']['value'])
            dois.append(r['group'][work]['work-summary'][0]['external-ids']['external-id'][ext_id]['external-id-value'])
            
for doi in dois:
    doi_r = requests.get(f"https://api.crossref.org/works/{doi}",headers = {'User-Agent':'Mozilla/5.0', 'accept' : 'application/json'})
    doi_r=doi_r.json()

    author_names_for_each_doi=[]

    for author in range(len(doi_r['message']['author'])):
        author_names_for_each_doi.append(doi_r['message']['author'][author]['given']+" "+doi_r['message']['author'][author]['family'])
    
    author_names_for_each_doi=", ".join(str(x) for x in author_names_for_each_doi)
    author_names.append(author_names_for_each_doi)

out_dict={
    'titles':titles,
    'journals':journals,
    'years':years,
    'doi_URLs':doi_URLs,
    'dois':dois,
    'author_names':author_names
    }

df=pd.DataFrame(out_dict)
df.to_csv('works.csv',index=False)
df
# Out:
#                                                titles  \
# 0   A single-cell comparison of adult and fetal hu...
# 1   Single-cell transcriptomics for the assessment...
# 2   Pathogenic variants damage cell composition an...
# 3   Impact of COVID-19 pandemic on cardiac rhythm ...
# 4   Identifying predictive risk factors for perman...
# 5   Multi-ancestry GWAS of the electrocardiographi...
# 6   Pulsed Levosimendan in advanced heart failure ...
# 7   Clinical outcomes of bioresorbable vascular sc...
# 8   Catastrophic antiphospholipid syndrome causing...
# 9   Regulatory and occupational considerations in ...
# 10  Ventricular pro-arrhythmic phenotype, arrhythm...
# 11  A New Approach to an Old Problem: One Brave Idea.
# 12  TCT-405 Optical coherence tomography-guided op...
# 13  HEMODYNAMIC LESION SIGNIFICANCE IS ASSOCIATED ...
# 14  Long-term follow-up of patients undergoing fre...
# 15  The cardiac sympathetic co-transmitter galanin...
# 16  Galanin reduces cardiac vagal acetylcholine re...
#
#                                              journals years  \
# 0                      Nature Cardiovascular Research  2022
# 1                           Nature Reviews Cardiology  2022
# 2                                             Science  2022
# 3                                     Heart rhythm O2  2022
# 4                              European Heart Journal  2021
# 5                               Nature communications  2020
# 6                European heart journal. Case reports  2020
# 7   EuroIntervention : journal of EuroPCR in colla...  2019
# 8                                    BMJ case reports  2019
# 9                                            Medicine  2018
# 10               Mechanisms of ageing and development  2018
# 11                               Circulation research  2018
# 12      Journal of the American College of Cardiology  2016
# 13      Journal of the American College of Cardiology  2016
# 14                European Journal of Plastic Surgery  2013
# 15       Journal of molecular and cellular cardiology  2011
# 16                                  The FASEB Journal  2010
#
#                                              doi_URLs  \
# 0          https://doi.org/10.1038/s44161-022-00183-w
# 1          https://doi.org/10.1038/s41569-022-00805-7
# 2             https://doi.org/10.1126/science.abo1984
# 3          https://doi.org/10.1016/j.hroo.2022.05.013
# 4      https://doi.org/10.1093/eurheartj/ehab724.2181
# 5          https://doi.org/10.1038/s41467-020-15706-x
# 6               https://doi.org/10.1093/ehjcr/ytaa080
# 7              https://doi.org/10.4244/eij-d-18-00262
# 8             https://doi.org/10.1136/bcr-2018-225495
# 9         https://doi.org/10.1016/j.mpmed.2018.08.003
# 10          https://doi.org/10.1016/j.mad.2018.05.004
# 11      https://doi.org/10.1161/circresaha.118.310941
# 12         https://doi.org/10.1016/j.jacc.2016.09.540
# 13      https://doi.org/10.1016/s0735-1097(16)30374-6
# 14          https://doi.org/10.1007/s00238-013-0826-3
# 15        https://doi.org/10.1016/j.yjmcc.2011.11.016
# 16  https://doi.org/10.1096/fasebj.24.1_supplement...
#
#                                      dois  \
# 0              10.1038/s44161-022-00183-w
# 1              10.1038/s41569-022-00805-7
# 2                 10.1126/science.abo1984
# 3              10.1016/j.hroo.2022.05.013
# 4          10.1093/eurheartj/ehab724.2181
# 5              10.1038/s41467-020-15706-x
# 6                   10.1093/ehjcr/ytaa080
# 7                  10.4244/eij-d-18-00262
# 8                 10.1136/bcr-2018-225495
# 9             10.1016/j.mpmed.2018.08.003
# 10              10.1016/j.mad.2018.05.004
# 11          10.1161/circresaha.118.310941
# 12             10.1016/j.jacc.2016.09.540
# 13          10.1016/s0735-1097(16)30374-6
# 14              10.1007/s00238-013-0826-3
# 15            10.1016/j.yjmcc.2011.11.016
# 16  10.1096/fasebj.24.1_supplement.625.11
#
#                                          author_names
# 0   Vincent R. Knight-Schrijver, Hongorzul Davaapi...
# 1   Antonio M. A. Miranda, Vaibhao Janbandhu, Henr...
# 2   Daniel Reichart, Eric L. Lindberg, Henrike Maa...
# 3   Wern Yew Ding, James Cranley, David Begley, Ar...
# 4   J Li, A Christodoulidou, J Cranley, F Ara, C.H...
# 5   Ioanna Ntalla, Lu-Chen Weng, James H. Cartwrig...
# 6    James Cranley, Antonia Hardiman, Leisa J Freeman
# 7   Vincent Floré, Adam J. Brown, Joel P. Giblett,...
# 8   James Cranley, Unni Krishnan, Katharine Tweed,...
# 9                      James Cranley, Catriona Bhagra
# 10  Shiraz Ahmad, Haseeb Valli, Karan R. Chadda, J...
# 11                     James Cranley, Calum A. MacRae
# 12  Vincent Floré, Adam Brown, James Cranley, Joel...
# 13  Adam J. Brown, Unni Krishnan, Joel Giblett, Ja...
# 14  Dipender Gill, David J. Bruce, Mark J. Ponsfor...
# 15  Neil Herring, James Cranley, Michael N. Lokale...
# 16  Neil Herring, James Cranley, Michael N Lokale,...
